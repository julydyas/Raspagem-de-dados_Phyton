# %% [markdown]
# ### FATEC - Análise e desenvolvimento de Sistema - Turma A
# #### Grupo: Juliana A L Dias e Stephanie Costa
# #### Tema: Análise do número de pessoas com tuberculose devido ao tabagismo no Brasil nos últimos 10 anos.
# #### Motivação:
# Tomamos conhecimento de uma noticía da Veja que o tabagismo por tuberculose pode causar 40  milhões de mortes a mais até 2050.
# Em pesquisa rápida de uma noticía da Veja na internet "uma perigosa mistura pode levar ao aumento no número de casos de tuberculose em todo o mundo entre 2010 e 2050. Países pobres, nos quais a incidência de tuberculose é alta, estão recebendo cada vez mais investimentos da indústria do cigarro."
# ficamos impressionadas e decidimos averiguar mais esse caso em particular.
# A partir disto, decidimos verificar como tem sido a taxa de crescimento do contágio ao longo dos últimos 10 anos, assim como identificar quais estados em que são notificadas.
# #### Fonte: DATASUS - http://tabnet.datasus.gov.br/cgi/tabcgi.exe?sinannet/cnv/tubercbr.def

# %% [markdown]
# ### Estados notificados de tuberculos devido ao tabagismo de 2007 a 2017

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
tbc=pd.read_excel('C:\\Users\\stephanie\\Documents\\1ºSemestreFatec\\fernandoMasanori\\datasustabagismo.xlsx')
#carregando planilha excel
tbc.head()
#para ver as primeiras linhas
#agora os dados estão tabelados corretamente
# Out:
#   Estado de notifição        Região  ano 2007  ano 2008  ano 2009  ano 2010  \
# 0            Rondônia  Região Norte         0         0         0         0
# 1                Acre  Região Norte         0         0         0         0
# 2            Amazonas  Região Norte         0         0         0         0
# 3             Roraima  Região Norte         0         0         0         0
# 4                Pará  Região Norte         4         0         0         0
#
#    ano 2011  ano 2012  ano 2013  ano 2014  ano 2015  ano 2016  ano 2017
# 0         0         0         0        12       102       131       172
# 1         0         0         0         0        53        91       117
# 2         1         1         3        31       341       363       477
# 3         0         0         0         3        32        31        51
# 4         0         1         3        47       353       557       617

# %%
tbc.info()
#Verificando a quantidade de linhas, colunas e se há valores nulos ou incorretos
#index27: sao 27 linhas, columns13: são 13 colunas
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 13 columns):
# Estado de notifição    27 non-null object
# Região                 27 non-null object
# ano 2007               27 non-null int64
# ano 2008               27 non-null int64
# ano 2009               27 non-null int64
# ano 2010               27 non-null int64
# ano 2011               27 non-null int64
# ano 2012               27 non-null int64
# ano 2013               27 non-null int64
# ano 2014               27 non-null int64
# ano 2015               27 non-null int64
# ano 2016               27 non-null int64
# ano 2017               27 non-null int64
# dtypes: int64(11), object(2)
# memory usage: 2.6+ KB

# %%
tbc.tail()
#para ver as ultimas linhas
# Out:
#    Estado de notifição               Região  ano 2007  ano 2008  ano 2009  \
# 22   Rio Grande do Sul           Região Sul         4         9         3
# 23  Mato Grosso do Sul  Região Centro-Oeste         1         1         0
# 24         Mato Grosso  Região Centro-Oeste         0         0         0
# 25               Goiás  Região Centro-Oeste         0         0         0
# 26    Distrito Federal  Região Centro-Oeste         0         0         0
#
#     ano 2010  ano 2011  ano 2012  ano 2013  ano 2014  ano 2015  ano 2016  \
# 22         6         8         9        40       399      1944      2057
# 23         0         0         2         9        33       134       203
# 24         0         1         7         9        60       193       264
# 25         2         0         1         4        36       275       289
# 26         0         0         1         4        20        55        79
#
#     ano 2017
# 22      2203
# 23       286
# 24       298
# 25       367
# ...

# %%
# Plotando gráfico de 2007 á 2017, usando ascending=False (para ordem decrescente) e x=estados de notificação
a= tbc.sort_values(by= ["ano 2007","ano 2008","ano 2009","ano 2010","ano 2011","ano 2012","ano 2013","ano 2014","ano 2015","ano 2016","ano 2017"],ascending=False).head().plot(kind="barh", grid=(True), xticks=(0,550,1100,1650,2200,2750,3300,3850,4400,4950,5500), x=("Estado de notifição"),figsize=(20,10), fontsize=(16))
a.set_title("Notificações de tuberculose devido ao tabagismo por estados no Brasil ", fontsize=(20));
a.set_xlabel("Número de notificações de tuberculose devido ao tabagismo", fontsize=(18));
a.set_ylabel("Estados notificados", fontsize=(18));

# %% [markdown]
# ### Análise dos útlimos 10 anos
# Analisando os estados notificados nos últimos 10 anos, pode-se fazer as seguintes observações:
# #### Pará Maior queda:
# Estado que apresentou menor número de casos de tubercolose por tabagismo notificados ao longo dos últimos 10 anos, porém em meados de 2015 tornou a crescer o número da doença.
# #### São Paulo (SP) Maior aumento:
# Estado que apresentou maior aumento de notificações ao longo dos últimos 10 anos. Em meados de 2010 houve pequena redução, mas a partir do ano seguinte tornou a apresentar crescimento das notificações.

# %% [markdown]
# ### Conclusão:
# #### Relacionado aos dados
# É fato que há um crescimento expressivo do números de pessoas infectadas por tuberculose através do tabagismo no Brasil.
# Pôde-se observar que há maior concentração das notificações na região sudeste São Paulo e Rio de Janeiro, em que concentram as cidades mais populosas do Brasil.
# É possível ver que ano após ano tem aumentado o contágio de tuberculose através do tabagismo, e certamente é algo que o ministério da saúde e da educação deve atuar para conscientar a população quanto aos sintomas, combate e prevenção da doença.
# ##### Combate:
# Este dado é alarmante, e através destes dados pode-se ver que é necessário campanhas e ações emergenciais focando o público fumante.
#
# #### Relacionado a atividade de raspagem e análise dos dados via phton-jupyter
# Realizar a análise de dados em Python tem as facilidades de: gerar métricas, gráficos, organizar dados entre outros.
# Contudo, aos que estão iniciando esta tarefa há diversas dificuldade em aprender a utilizar as bibliotecas, suas funções assim como principais comando de dataframe.
# Em adicional, as tabelas exportadas dos sites vem com dados não tratados, e por isso demanda um tempo considerável em tratá-los para uso posterior.
#
# #### Experiência pessoal
# Contudo, com as dificuldades encontradas no trabalho, pudemos compreender a importância que é fazer uma análise de dados.
